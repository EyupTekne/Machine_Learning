# %% [markdown]
# <a href="https://colab.research.google.com/github/EyupTekne/Machine_Learning/blob/main/visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

# %%
years=[1950,1960,1970,1980,1990,2000,2010]
gdp=[300.2,543.3,1075.9,2862.5,5979.6,10289.7,14958.3]

plt.plot(years,gdp,color='green',marker='o',linestyle='solid')
plt.title("Nominal GDP")
plt.ylabel("Billions of $")
plt.show()

# %%
movies=["Annie Hall","Ben-Hur","Casabalanca","Gandhi","West Side Story"]
num_oscars=[5,11,3,8,10]


xs=[i for i,_ in enumerate(movies)]

plt.bar(xs,num_oscars)
plt.ylabel("# of Academy Awars")
plt.title("My Favorite Movies")

plt.xticks([i for i,_ in enumerate(movies)],movies)
plt.show()

# %%
movies=["Annie Hall","Ben-Hur","Casabalanca","Gandhi","West Side Story"]
num_oscars=[5,11,3,8,10]


#plt.gca().clear()

movies=["Annie Hall","Ben-Hur","Casablanca","Gandhi","West Side Story"]
num_oscars=[5,11,3,8,10]

#plot bar with left x-coordinates [xs],heights [num_oscars]
plt.bar(range(len(movies)),num_oscars)
plt.ylabel("# of Academy Awards") #add a title
plt.title("My favorite Movies") #label the y-axis
#label x-axis with movie names at bar centers
plt.xticks(range(len(movies)),movies)
plt.show()

# %%
from collections import Counter
grades=[83,95,91,87,70,0,85,82,100,67,73,77,0]

histogram=Counter(min(grade//10*10,90) for grade in grades)

plt.bar([x+5 for x in histogram.keys()],
        histogram.values(),
        10,
        edgecolor=(0,0,0))
plt.axis([-5,105,0,5])
plt.xticks([10*i for i in range(11)])
plt.xlabel("Decile")
plt.ylabel("# of Students")
plt.title("Distribution of Exam 1 Grades")
plt.show()

# %%
mentions=[500,505,482]
years=[2017,2018,2019]
plt.bar(years,mentions,0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data science'")



plt.ticklabel_format(useOffset=False)
plt.axis([2016.5,2019.5,480,510])
plt.title("Look at the 'Huge' Increase!")
plt.show()

# %%
mentions=[500,505,482]
years=[2017,2018,2019]
plt.bar(years,mentions,0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data science'")



plt.ticklabel_format(useOffset=False)
plt.axis([2016.5,2019.5,0,550])
plt.title("Not So Huge Anymore!")
plt.show()

# %%
variance=[1,2,4,8,16,32,64,128,256]
bias_squared=[256,128,64,32,16,8,4,2,1]
total_error = [x+y for x,y in zip(variance,bias_squared)]
xs=[i for i, _ in enumerate(variance)]

# we can mak e multiple calls to pt.plot
#to.show multiple series on the same chart

plt.plot(xs,variance,'g-',label='variance')
plt.plot(xs,bias_squared,'r-.',label='bias^2')
plt.plot(xs,total_error, 'b:',label='total error')

#Because we've assigned labels to each series,
#we cab get a legend for free (loc=9 means "top center")

plt.legend(loc=9)
plt.xlabel("model complexity")

#plt.xticks([])

plt.title("The Bias-Variance Tradeoff")
plt.show()

# %%
friends=[70,65,72,63,71,64,60,64,67]
minutes=[175,170,205,120,220,130,105,145,190]
labels=['a','b','c','d','e','f','g','h','i']
plt.scatter(friends,minutes)
#label each point
for label,friend_count,minute_count in zip(labels,friends,minutes):
    plt.annotate(label,
                 xy=(friend_count,minute_count),# Put he label with its point
                 xytext=(5,-5),                 #but slightly offset
                 textcoords='offset points')
    plt.title("Daily Minutes vs. Number of Friends")
    plt.xlabel("# of friends")
    plt.ylabel("daily minutes spent on the site")
plt.show()

# %%
friends=[70,65,72,63,71,64,60,64,67]
minutes=[175,170,205,120,220,130,105,145,190]
labels=['a','b','c','d','e','f','g','h','i']
plt.scatter(friends,minutes)
#label each point
for label,friend_count,minute_count in zip(labels,friends,minutes):
    plt.annotate(label,
                 xy=(friend_count,minute_count),# Put he label with its point
                 xytext=(5,-5),                 #but slightly offset
                 textcoords='offset points')
    plt.title("Daily Minutes vs. Number of Friends")
    plt.xlabel("# of friends")
    plt.axis("equal")
    plt.ylabel("daily minutes spent on the site")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.DataFrame({
    'scores':[56,67,45,89,90,72,78,88,94,60,73,81,85,68,77]
})
data['scores'].hist(bins=8,edgecolor='black')
plt.title('Histogram of Exam  Scores')
plt.xlabel('Score')
plt.ylabel('Number of Students')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# Regular Python list (array) of data
scores = [56,67,45,89,90,72,78,88,94,60,73,81,85,68,77]

# Create histogram
plt.hist(scores, bins=8, edgecolor='black')

# Add labels and title
plt.title('Histogram of Exam  Scores')
plt.xlabel('Score')
plt.ylabel('Number of Students')

# Display the plot
plt.show()

# %%
import seaborn as sns
sns.histplot(data['scores'],bins=8,kde=True)
plt.title('Histogram of Exam  Scores')
plt.show()

# %%
class_A=[56,67,45,89,90,72,78,88,94,60]
class_B=[66,70,65,80,85,79,90,88,84,73]
class_C=[50,52,47,60,65,70,75,78,72,68]

plt.boxplot([class_A,class_B,class_C],labels=["Class A","Class B","Class C"])
plt.title("Box Plot of Exam Scores")
plt.xlabel("Class")
plt.ylabel("Score")
plt.show()
# Out:
# /tmp/ipython-input-4214514242.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([class_A,class_B,class_C],labels=["Class A","Class B","Class C"])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data=[
    [88,92,80,89,100],
    [78,85,70,83,90],
    [90,91,85,87,93],
    [65,70,72,68,75],
    [95,98,96,92,99]
]
subjects=["Math","Science","English","History","Art"]
students=["Alice","Bob","Charlie","David","Eve"]

sns.heatmap(data,annot=True,fmt="d",
            xticklabels=subjects,
            yticklabels=students,
            cmap="YlGnBu")
plt.title("Students Exam Scores Heatmap")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data=[
    [88,92,80,89,100],
    [78,85,70,83,90],
    [90,91,85,87,93],
    [65,70,72,68,75],
    [95,98,96,92,99]
]
subjects=["Math","Science","English","History","Art"]
students=["Alice","Bob","Charlie","David","Eve"]

sns.heatmap(data,annot=True,fmt="d",
            xticklabels=subjects,
            yticklabels=students,
            cmap="YlGnBu")
plt.title("Students Exam Scores Heatmap")
plt.show()

# %%
import matplotlib.pyplot as plt

labels=['Apples','Bananas','Cherries','Dates']
sizes=[30,25,25,20]
colors=['red','gold','pink','brown']
explode=(0.1,0,0,0)

plt.figure(figsize=(6,6))
plt.pie(sizes,
        explode=explode,
        labels=labels,
        colors=colors,
        autopct='%1.1f%%',
        shadow=True,
        startangle=140)
plt.title('Fruit Market Share')
plt.axis('equal')
plt.show()

# %%
#Line Plot:Sine&Cosine

import numpy as np
import matplotlib.pyplot as plt

# Veriler
x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Desinger
plt.plot(x, y1, label='sin(x)')
plt.plot(x, y2, label='cos(x)')

plt.title('Sine and Cosine')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Bar Chart of Category Counts Task:Given categories ['A','B','C','D'] and counts [12,7,19,51],makes a bar chart with title and axis labels
import matplotlib.pyplot as plt

# Data for categories and counts
categories = ['A', 'B', 'C', 'D']
counts = [12, 7, 19, 51]

# Create the bar chart
plt.figure(figsize=(8, 6))
plt.bar(categories, counts, color='skyblue')

# Add labels and title
plt.title('Category Counts')
plt.xlabel('Categories')
plt.ylabel('Counts')

# Display the plot
plt.show()

# %%
#Histogram of Random Data

import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(0, 1, 1000)

plt.hist(data, bins=30, color='orange', edgecolor='black')
plt.title('Histogram of Random Normal Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
#Scatter with a trend Task:create x from 0 to 10(80 points) and y=0.8x+noise. plot a scatter,add title and labels
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to 10 with 80 points
x = np.linspace(0, 10, 80)

# Generate y values with noise added to the linear relation y = 0.8x
noise = np.random.normal(0, 0.5, size=x.shape)  # Noise with standard deviation of 0.5
y = 0.8 * x + noise

# Create the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='purple', edgecolor='black')

# Add labels and title
plt.title('Scatter Plot with a Trend (y = 0.8x + noise)')
plt.xlabel('x values')
plt.ylabel('y values')

# Display the plot
plt.show()

# %%
# Pie Chart of Proportions
import matplotlib.pyplot as plt

labels = ['North', 'South', 'East', 'West']
shares = [40, 25, 20, 15]

plt.pie(shares, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart of Proportions')
plt.show()
